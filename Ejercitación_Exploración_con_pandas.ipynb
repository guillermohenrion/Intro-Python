# %% [markdown]
# <a href="https://colab.research.google.com/github/guillermohenrion/Intro-Python/blob/master/Ejercitaci%C3%B3n_Exploraci%C3%B3n_con_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Covid-19: comparación entre paises
#
# Datos actualizados a diario tomados desde: [CSSEGISandData / COVID-19](https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data)

# %%
# Recuperar datos desde el sitio mencionado:

# https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv
# https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv
# https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv

# %%
## Incorporar a un data frame de pandas 
#import pandas as pd
#df_covid_c = ?
#df_covid_d = ?
#df_covid_r = ?
## Mostrar qué información existe y en qué formato
#df_covid_c.describe()

# %%
##Ver cómo visualizar un bloxplot con los útlimos tres días disponibles para los confirmados
##df_covid.boxplot(?)

# %%
##Realizar un gráfico golobal del útimo día disponible de confirmados ordenado de menor a moyor por nro. de casos
##Utilizar sor_values by el último día disponible y graficar

# %%
##Trasponer los confirmados para que quede paises como columnas y fechas como filas
##Usar transpose

# %%
##Mostrar el describe para Argentia y gráfico ordenado por fecha

# %%
##Boxplot para Argentina

# %%
##Considerar para Argentina solo desde el comienzo de la casoso confirmados (t0)
##Y repetir para dos paises más
##Concatenar los data frame de manera de poder comparar entre ellos tomando como referencia el t0 de cada uno
##Filtar por cantidad de casos > 0
#df_covid_t0_Argentina=?
#df_covid_t0_Spain=?

# %%
##Con Plotly
##Unir casos por pais y visualizar curvas por pais de confirmados
#import plotly.express as px
##Armar data frame con una colmna Pais y otra confimados, un pais debajo del otro
#df_confirmados=pd.concat([
#    df_covid_t0_Argentina,df_covid_t0_Chile, df_covid_t0_Italia, df_covid_t0_Spain
#],ignore_index=True).drop_duplicates().reset_index(drop=True)
#fig = px.line(df_confirmados,  y="Confirmados", color='Pais'.....
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3726aa78-7ba9-47b2-b302-1e42889641d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3726aa78-7ba9-47b2-b302-1e42889641d7")) {
#                     Plotly.newPlot(
#                         '3726aa78-7ba9-47b2-b302-1e42889641d7',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Argentina<br>Confirmados=%{y}", "legendgroup": "Pais=Argentina", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Pais=Argentina", "showlegend": true, "type": "scatter", "xaxis": "x", "y": [1, 2, 8, 12, 17, 19, 31, 34, 45, 56, 68, 79, 97, 128, 158, 266, 301, 387, 502, 589, 690, 745, 820, 1054, 1133, 1265, 1451, 1554, 1628, 1715, 1795, 1975, 2142, 2208, 2277, 2443, 2571, 2669, 2758, 2839, 2941, 3031, 3144, 3435, 3607, 3780, 3892], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Chile<br>Confirmados=%{y}", "legendgroup": "Pais=Chile", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "Pais=Chile", "showlegend": true, "type": "scatter", "xaxis": "x", "y": [1, 4, 8, 13, 23, 43, 61, 74, 155, 201, 238, 434, 537, 632, 746, 922, 1142, 1306, 1610, 1909, 2139, 2449, 2738, 3031, 3404, 3737, 4161, 4471, 4815, 5116, 5546, 5972, 6501, 6927, 7213, 7525, 7917, 8273, 8807, 9252, 9730, 10088, 10507, 10832, 11296, 11812, 12306, 12858, 13331], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Italia<br>Confirmados=%{y}", "legendgroup": "Pais=Italia", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "Pais=Italia", "showlegend": true, "type": "scatter", "xaxis": "x", "y": [2, 3, 20, 62, 155, 229, 322, 453, 655, 888, 1128, 1694, 2036, 2502, 3089, 3858, 4636, 5883, 7375, 9172, 10149, 12462, 17660, 21157, 24747, 27980, 31506, 35713, 41035, 47021, 53578, 59138, 63927, 69176, 74386, 80589, 86498, 92472, 97689, 101739, 105792, 110574, 115242, 119827, 124632, 128948, 132547, 135586, 139422, 143626, 147577, 152271, 156363, 159516, 162488, 165155, 168941, 172434, 175925, 178972, 181228, 183957, 187327, 189973, 192994, 195351, 197675], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Espa\u00f1a<br>Confirmados=%{y}", "legendgroup": "Pais=Espa\u00f1a", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "Pais=Espa\u00f1a", "showlegend": true, "type": "scatter", "xaxis": "x", "y": [1, 2, 6, 13, 15, 32, 45, 84, 120, 165, 222, 259, 400, 500, 673, 1073, 1695, 2277, 5232, 6391, 7798, 9942, 11748, 13910, 17963, 20410, 25374, 28768, 35136, 39885, 49515, 57786, 65719, 73235, 80110, 87956, 95923, 104118, 112065, 119199, 126168, 131646, 136675, 141942, 148220, 153222, 158273, 163027, 166831, 170099, 172541, 177644, 184948, 190839, 191726, 198674, 200210, 204178, 208389, 213024, 219764, 223759, 226629], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...

# %%
#La forma genérica finalmente sería
#Analizar y ver si se puede optimizar

dfg=pd.DataFrame()
df_covid_t0_p={}
cp = ['Argentina', 'Chile', 'Spain', 'Italy', 'China', 'Brazil', 'US', 'Australia']
#for c in df_covid_t.columns: # Selecciono algunos, porque con todos no se entiende em gráfico
for c in cp:
  dfp=df_covid_t0[c]
  dfp=dfp[dfp>0]
  cnp=dfp.count()
  colp=[c]*cnp
  dfp2=pd.DataFrame(dfp)
  dfp2.insert(1, "Pais", colp, True)
  dfp2.columns=['Confirmados', 'Pais']
  dfg=pd.concat([dfg ,dfp2],ignore_index=True).drop_duplicates().reset_index(drop=True)

fig = px.line(dfg,  y="Confirmados", color='Pais', title="Confirmados por pais (ref.T0)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="468b1850-b3ae-4cac-ad15-72b91186db8c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("468b1850-b3ae-4cac-ad15-72b91186db8c")) {
#                     Plotly.newPlot(
#                         '468b1850-b3ae-4cac-ad15-72b91186db8c',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Argentina<br>Confirmados=%{y}", "legendgroup": "Pais=Argentina", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Pais=Argentina", "showlegend": true, "type": "scatter", "xaxis": "x", "y": [1, 2, 8, 12, 17, 19, 31, 34, 45, 56, 68, 79, 97, 128, 158, 266, 301, 387, 502, 589, 690, 745, 820, 1054, 1133, 1265, 1451, 1554, 1628, 1715, 1795, 1975, 2142, 2208, 2277, 2443, 2571, 2669, 2758, 2839, 2941, 3031, 3144, 3435, 3607, 3780, 3892], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Chile<br>Confirmados=%{y}", "legendgroup": "Pais=Chile", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "Pais=Chile", "showlegend": true, "type": "scatter", "xaxis": "x", "y": [1, 4, 8, 13, 23, 43, 61, 74, 155, 201, 238, 434, 537, 632, 746, 922, 1142, 1306, 1610, 1909, 2139, 2449, 2738, 3031, 3404, 3737, 4161, 4471, 4815, 5116, 5546, 5972, 6501, 6927, 7213, 7525, 7917, 8273, 8807, 9252, 9730, 10088, 10507, 10832, 11296, 11812, 12306, 12858, 13331], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Spain<br>Confirmados=%{y}", "legendgroup": "Pais=Spain", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "Pais=Spain", "showlegend": true, "type": "scatter", "xaxis": "x", "y": [1, 2, 6, 13, 15, 32, 45, 84, 120, 165, 222, 259, 400, 500, 673, 1073, 1695, 2277, 5232, 6391, 7798, 9942, 11748, 13910, 17963, 20410, 25374, 28768, 35136, 39885, 49515, 57786, 65719, 73235, 80110, 87956, 95923, 104118, 112065, 119199, 126168, 131646, 136675, 141942, 148220, 153222, 158273, 163027, 166831, 170099, 172541, 177644, 184948, 190839, 191726, 198674, 200210, 204178, 208389, 213024, 219764, 223759, 226629], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Italy<br>Confirmados=%{y}", "legendgroup": "Pais=Italy", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "Pais=Italy", "showlegend": true, "type": "scatter", "xaxis": "x", "y": [2, 3, 20, 62, 155, 229, 322, 453, 655, 888, 1128, 1694, 2036, 2502, 3089, 3858, 4636, 5883, 7375, 9172, 10149, 12462, 17660, 21157, 24747, 27980, 31506, 35713, 41035, 47021, 53578, 59138, 63927, 69176, 74386, 80589, 86498, 92472, 97689, 101739, 105792, 110574, 115242, 119827, 124632, 128948, 132547, 135586, 139422, 143626, 147577, 152271, 156363, 159516, 162488, 165155, 168941, 172434, 175925, 178972, 181228, 183957, 187327, 189973, 192994, 195351, 197675], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=China<br>Confirmados=%{y}", "legendgroup": "Pais=China", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "Pais=China", "showlegend": true, "type": "scatter", "xaxis": "x", "y": [643, 920, 1406, 2075, 2877, 5509, 6087, 8141, 9802, 11891, 16630, 19716, 23707, 27440, 30587, 34110, 36814, 39829, 42354, 44386, 44759, 59895, 66358, 68413, 70513, 72434, 74211, 74619, 75077, 75550, 77001, 77022, 77241, 77754, 78166, 78600, 78928, 79356, 79932, 80136, 80261, 80386, 80537, 80690, 80770, 80823, 80860, 80887, 80921, 80932, 80945, 80977, 81003, 81033, 81058, 81102, 81156, 81250, 81305, 81435, 81498, 81591, 81661, 81782, 81897, 81999, 82122, 82198, 82279, 82361, 82432, 82511, 82543, 82602, 82665, 82718, 82809, 82883, 82941, 83014, 83134, 83213, 83306, 83356, 83403, 83760, 83787, 83805, 83817, 83853, 83868, 83884, 83899, 83909, 83912], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Brazil<br>Confirmados=%{y}", "legendgroup": "Pais=Brazil", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "lines", "name": "Pais=Brazil", "showlegend": true, "type": "scatter", "xaxis": "x", "y": [1, 2, 4, 13, 20, 25, 31, 38, 52, 151, 162, 200, 321, 372, 621, 793, 1021, 1546, 1924, 2247, 2554, 2985, 3417, 3904, 4256, 4579, 5717, 6836, 8044, 9056, 10360, 11130, 12161, 14034, 16170, 18092, 19638, 20727, 22192, 23430, 25262, 28320, 30425, 33682, 36658, 38654, 40743, 430 ...
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale":

# %%
#Mostrar los confirmados a la última fecha disponible

# %%
#Utilizanfo geopy realizar mapa de confirmados 
#Se camnbia el ícono para eso hay que descargar el ícono circle_red 
rom geopy.geocoders import Nominatim
import folium
import base64
import io

mapa = folium.Map(location=(-34.6131516,	 -58.3772316), zoom_start=4)

for index,row in dfc.iterrows(): 
  icon_url = 'https://upload.wikimedia.org/wikipedia/commons/9/9e/WX_circle_red.png'

  icon = folium.features.CustomIcon(icon_url,icon_size=(max(row['Confirmados']/10000,5), max(row['Confirmados']/10000, 5)))  # Creating a custom Icon

  folium.Marker(location=(row['Lat'],row['Long']),  icon=icon, tooltip=row['Confirmados']).add_to(mapa)

display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
