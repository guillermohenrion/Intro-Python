# %% [markdown]
# <a href="https://colab.research.google.com/github/guillermohenrion/Intro-Python/blob/master/intro_colab_%26_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Agenda
#
# * Presentación Google Colab
#
#   * Entorno
#   * Markdown
#   * Editor de código
#
# * Python
#
#   * Listas, números, cadenas
#   * Pandas
#   * Numpy
#   * Leer un archivo en colab
#   * Gráficos

# %% [markdown]
# <p><img alt="Colaboratory logo" height="45px" src="/img/colab_favicon.ico" align="left" hspace="10px" vspace="0px"></p>
#
# <h1>¿Qué es Colaboratory?</h1>
#
# Colaboratory, o Colab, te permite escribir y ejecutar código de Python en un navegador, dentro de documentos en los que se puede combinar texto con formato excrito en lenguaje Markdown y código de manera que:
#
# - No sea requerida una configuración
# - Acceso gratuito a GPU
# - Facilidad para compartir
#
# Una vez que levanta la Notebook que les compartí deben abrir un sitio de pruebas que es una copia local sobre la cual pueden trabajar.
#
# [https://colab.research.google.com/](https://colab.research.google.com/)
#
#
#
# ---
#
# Existen dos tipos de celdas: Códgio o Texto

# %% [markdown]
# ## Texto en lenguaje Markdown

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# # Texto título nivel 1
#
# ## Texto título nivel 2
#
# $f_r(x)=rx (1-x)$
#
# $\lambda(r)=\lim\limits_{n\rightarrow\infty}\frac{1}{n}
# \sum_{i=0}^{n-1}\log\begin{vmatrix}\frac{d_{f_r}}{d_x}(x^{(r)}_i)\end{vmatrix}$
#
# [Intro a Markdown](https://www.markdownguide.org/getting-started/)
#
# ![](https://sitiobigdata.com/wp-content/uploads/2019/02/google-colab.jpeg)
#
# ----
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Python
#
# Python es un lenguaje de programación poderoso y fácil de aprender. Cuenta con estructuras de datos eficientes y de alto nivel y un enfoque simple pero efectivo a la programación orientada a objetos. La elegante sintaxis de Python y su tipado dinámico, junto con su naturaleza interpretada, hacen de éste un lenguaje ideal para scripting y desarrollo rápido de aplicaciones en diversas áreas y sobre la mayoría de las plataformas.
#
# [http://www.python.org.ar/](http://www.python.org.ar/)
#
#
# * [Números y listas](https://colab.research.google.com/drive/1KgLbZ9afkEUTXhoGePlFwFesxAvpF9QJ)
#
# * [Cadenas y tuplas](https://colab.research.google.com/drive/1I5yN7BnWSSCCrMnnXzXDJPX0FomumHy_)
#
# * [Funciones](https://colab.research.google.com/drive/1WLLLe9iKewx1ZiVlXJZSqWuBWcxmgSRi)
#
# * [Estructuras de control](https://colab.research.google.com/drive/1iHBM4R0NNQfVHL5qwnx3m14jJxpG0f3k)
#
# * [Funciones](https://colab.research.google.com/drive/1GHI0UQR8vFgrhUUH6HPZM85FBL0gePSD)

# %% [markdown]
# ## Pandas
#
# [Pandas](https://colab.research.google.com/drive/1WG62-rGLkBujg0VJZ6iy1E3Ffi5xxwcH)

# %% [markdown]
# # Numpy
#
# [Numpy](https://colab.research.google.com/drive/1_P-pi3ZuayPbmg5MqR6mb8H3UmIjoSCS)

# %% [markdown]
# # Gráficos
#
# [Gráficos](https://colab.research.google.com/drive/15gvykYuokTVL6rIQQcZfcR50Osnx3u_I)
