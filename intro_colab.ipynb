# %% [markdown]
# <a href="https://colab.research.google.com/github/guillermohenrion/Intro-Python/blob/master/intro_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Agenda
#
# * Presentación Google Colab
#
#   * Entorno
#   * Markdown
#   * Editor de código
#
# * Python
#
#   * Listas, números, cadenas
#   * Pandas
#   * Numpy
#   * Leer un archivo en colab
#   * Gráficos

# %% [markdown]
# ## **Leer un archivo**

# %%
from google.colab import files
import pandas as pd

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  
df = pd.read_csv('alturas-pesos-mils-train-checkpoint.csv')
df.head()
# Out:
#      <input type="file" id="files-b363e141-c503-4334-8214-155f8905fd84" name="files[]" multiple disabled />
#      <output id="result-b363e141-c503-4334-8214-155f8905fd84">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving alturas-pesos-mils-train-checkpoint.csv to alturas-pesos-mils-train-checkpoint (3).csv
# User uploaded file "alturas-pesos-mils-train-checkpoint.csv" with length 240527 bytes
#    Unnamed: 0  Genero    Peso   Altura
# 0        7620   Mujer  61.235  162.402
# 1        1837  Hombre  97.432  181.908
# 2        3311  Hombre  73.324  172.459
# 3        9478   Mujer  55.193  157.748
# 4        7805   Mujer  56.886  151.798

# %% [markdown]
# ## **Visualizar data**

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x='mean(Miles_per_Gallon)',
  y='Origin',
  color='Origin'
)
# Out:
# alt.Chart(...)
